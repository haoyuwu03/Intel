# %%
#mount to drive
from google.colab import drive
drive.mount('/content/gdrive')

# %%
#open directory
# %cd /content/gdrive/My Drive/Colab Notebooks/YOLOv3

# %%
#get imports from requirements
from yolov3_training.utils import detect_image
from yolov3_training.yolov3 import create_yolov3

import tensorflow as tf

# %%
#define file locations
input_image = './image_data/test.jpg'
output_image = './image_data/test-bbox.jpg'

tf_coco_weights = './checkpoints/coco_weights/coco_weights'

# %%
yolo_model = create_yolov3()
yolo_model.load_weights(tf_coco_weights)

# %%
detect_image(yolo_model,image_path=input_image,output_path= output_image, show=True)
# Out:
# array([[[ 58,  53,  21],
#         [ 84,  79,  47],
#         [ 65,  60,  28],
#         ...,
#         [177, 174, 165],
#         [170, 168, 155],
#         [174, 168, 152]],
#
#        [[ 72,  67,  35],
#         [ 56,  51,  19],
#         [ 76,  71,  39],
#         ...,
#         [184, 184, 176],
#         [172, 170, 158],
#         [195, 192, 177]],
#
#        [[ 58,  54,  19],
#         [ 58,  54,  19],
#         [ 92,  88,  53],
#         ...,
#         [196, 197, 192],
#         [194, 195, 187],
#         [195, 195, 185]],
#
#        ...,
#
#        [[120, 138, 152],
#         [120, 138, 152],
#         [120, 138, 152],
#         ...,
#         [136, 154, 168],
#         [134, 152, 166],
#         [133, 151, 165]],
#
#        [[120, 138, 152],
#         [120, 138, 152],
#         [120, 138, 152],
#         ...,
#         [130, 148, 162],
#         [128, 146, 160],
#         [127, 145, 159]],
#
#        [[119, 138, 152],
#         [119, 138, 152],
#         [120, 138, 152],
# ...
